# %% [markdown]
# Instalando Pacote

# %%
# !pip install sacrebleu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 54.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 118.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.8 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=4f829abeeb1cace1448ba2eb96fe070d8b0d0b90524a10fa38c041fabb36073d
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
perc= 5

# %%
import pandas as pd

i=2



arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emotion/lambada/base_emotion_'+str(perc)+'_lambada'+str(i+1)+'.csv'
emotion = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emoint/lambada/base_emoint_'+str(perc)+'_lambada'+str(i+1)+'.csv'
emoint = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/ironic/lambada/base_ironic_'+str(perc)+'_lambada'+str(i+1)+'.csv'
ironic = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/offensive/lambada/base_offensive_'+str(perc)+'_lambada'+str(i+1)+'.csv'
offensive = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/lambada/base_tweet_sentiment_'+str(perc)+'_lambada'+str(i+1)+'.csv'
tweet_sentiment = pd.read_csv(arq, sep = ';', decimal = ',')

lambada = emotion.append([emoint, ironic, offensive, tweet_sentiment])


lambada.head()
# Out:
# <ipython-input-3-e505639f5b94>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lambada = emotion.append([emoint, ironic, offensive, tweet_sentiment])
#                                                texto  \
# 0  i know it shouldn t feel unsuccessful but the ...
# 1  i know it shouldn t feel unsuccessful but the ...
# 2  i know it shouldn t feel unsuccessful but the ...
# 3  i know it shouldn t feel unsuccessful but the ...
# 4  i know it shouldn t feel unsuccessful but the ...
#
#                                            generated  new_label
# 0  i know it shouldn t go like that but i have to...          0
# 1  i know it shouldn t have been posted but i sti...          1
# 2  i know it shouldn t have been there i should h...          0
# 3  i know it shouldn t be said but just because i...          1
# 4  i know it shouldn t have come to that and i ju...          0

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emotion/teste_algo/base_emotions_'+str(perc)+'_gptneokey'+str(i+1)+'.csv'
emotion = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emoint/teste_algo/base_emoint_'+str(perc)+'_gptneokey'+str(i+1)+'.csv'
emoint = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/ironic/teste_algo/base_ironic_'+str(perc)+'_gptneokey'+str(i+1)+'.csv'
ironic = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/offensive/teste_algo/base_offensive_'+str(perc)+'_gptneokey'+str(i+1)+'.csv'
offensive = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/teste_algo/base_tweet_sentiment_'+str(perc)+'_gptneokey'+str(i+1)+'.csv'
tweet_sentiment = pd.read_csv(arq, sep = ';', decimal = ',')

gpt_neo = emotion.append([emoint, ironic, offensive, tweet_sentiment])


gpt_neo.head()
# Out:
# <ipython-input-4-f536b061d8b7>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gpt_neo = emotion.append([emoint, ironic, offensive, tweet_sentiment])
#                                                texto  \
# 0  i feel like something tragic is going to have ...
# 1  i feel rotten and my frustration manifests as ...
# 2  i feel inadequate and i shut down and feel cro...
# 3                             i feel rather pathetic
# 4  i have succumbed to the dreaded commuter virus...
#
#                                            generated  new_label  prob_text
# 0   ive been so sad and feeling so useless on thi...          0   0.979626
# 1   ive felt rotten and ive just gotten a lot of ...          0   0.979414
# 2   ive shut down and i feel so inadequate and in...          0   0.979263
# 3   ive been feeling rather pathetic for the past...          0   0.979191
# ...

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
import sacrebleu

lambada['BLEUscore'] = lambada.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['generated'])]), axis=1)
gpt_neo['BLEUscore'] = gpt_neo.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['generated'])]), axis=1)
# Out:
# ...
# 100%|██████████| 7348/7348 [00:05<00:00, 1239.38it/s]

# %%
lambada['BLEUscore_without_bp'] = lambada['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
gpt_neo['BLEUscore_without_bp'] = gpt_neo['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
# Out:
# ...
# 100%|██████████| 7348/7348 [00:00<00:00, 396049.06it/s]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('sentence-transformers/paraphrase-albert-small-v2')

# %%
dataset = [ lambada,gpt_neo]

for base in dataset:
  original_embedding = model.encode(base['texto'].astype('str').to_numpy())
  base['texto_embedding'] = [original_embedding[i] for i in range(original_embedding.shape[0])]
  parafrase_embedding = model.encode(base['generated'].astype('str').to_numpy())
  base['generated_embedding'] = [parafrase_embedding[i] for i in range(parafrase_embedding.shape[0])]

# %%
for base in dataset:
  base['similiaridade_parafrase'] = base.progress_apply(lambda x:util.cos_sim(x['texto_embedding'], x['generated_embedding']).tolist()[0][0], axis=1)
# Out:
# ...
# 100%|██████████| 7348/7348 [00:00<00:00, 9557.62it/s]

# %%
lambada.describe()
# Out:
#          new_label  BLEUscore_without_bp  similiaridade_parafrase
# count  7435.000000           7435.000000              7435.000000
# mean      0.430800             26.868325                 0.479968
# std       0.507563             22.211212                 0.199368
# min       0.000000              0.000000                -0.053725
# 25%       0.000000             12.642037                 0.338713
# 50%       0.000000             19.228545                 0.475891
# 75%       1.000000             31.702331                 0.605985
# max       2.000000            100.000000                 1.000000

# %%
gpt_neo.describe()
# Out:
#          new_label    prob_text  BLEUscore_without_bp  similiaridade_parafrase
# count  7348.000000  7348.000000           7348.000000              7348.000000
# mean      1.238160     0.870993             13.718894                 0.557131
# std       1.314928     0.189585             16.462556                 0.192237
# min       0.000000     0.062488              0.000000                -0.098338
# 25%       0.000000     0.877382              4.141141                 0.435178
# 50%       1.000000     0.955723              8.194724                 0.570315
# 75%       2.000000     0.974202             15.973578                 0.697174
# max       5.000000     0.990057            100.000000                 1.000000
