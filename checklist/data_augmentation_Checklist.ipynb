# %% [markdown]
# # Imports and Setups

# %%
! pip install textattack
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.8/436.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 38.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 55.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 47.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 112.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 100.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 42.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 12.4 MB/s eta 0:00:00
# ...

# %%
! pip install tensorflow_text
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 58.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# Lendo o Arquivo

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# %%
num_gen = 5
perc = 5

# %%
from textattack.augmentation.recipes import CheckListAugmenter
augmenter = CheckListAugmenter(transformations_per_example=5)
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Emotion

# %%
nums = [1,2,3,4,5]
for i in nums:
  arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emotion/base_emotions_'+str(perc)+'_original'+str(i)+'.csv'
  base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')
  base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
  export = base_cru_1p.copy()
  export = export.explode('generated').reset_index(drop=True)
  arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emotion/checklist/base_emotions_'+str(perc)+'_checklist'+str(i)+'.csv'
  export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
# Out:
# ...
# 100%|██████████| 800/800 [01:28<00:00,  9.00it/s]

# %% [markdown]
# # Emoint

# %%
nums = [1,2,3,4,5]
for i in nums:
  arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emoint/base_emoint_'+str(perc)+'_original'+str(i)+'.csv'
  base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')
  base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
  export = base_cru_1p.copy()
  export = export.explode('generated').reset_index(drop=True)
  arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/emoint/checklist/base_emoint_'+str(perc)+'_checklist'+str(i)+'.csv'
  export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
# Out:
# ...
# 100%|██████████| 163/163 [00:18<00:00,  8.72it/s]

# %% [markdown]
# # Ironic

# %%
nums = [1,2,3,4,5]
for i in nums:
  arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/ironic/base_ironic_'+str(perc)+'_original'+str(i)+'.csv'
  base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')
  base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
  export = base_cru_1p.copy()
  export = export.explode('generated').reset_index(drop=True)
  arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/ironic/checklist/base_ironic_'+str(perc)+'_checklist'+str(i)+'.csv'
  export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
# Out:
#   0%|          | 0/144 [00:00<?, ?it/s]
# ...
# 2023-09-15 23:57:33,780 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# ...
# 100%|██████████| 144/144 [00:09<00:00, 15.04it/s]

# %% [markdown]
# # Offensive

# %%
nums = [1,2,3,4,5]
for i in nums:
  arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/offensive/base_offensive_'+str(perc)+'_original'+str(i)+'.csv'
  base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')
  base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
  export = base_cru_1p.copy()
  export = export.explode('generated').reset_index(drop=True)
  arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/offensive/checklist/base_offensive_'+str(perc)+'_checklist'+str(i)+'.csv'
  export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
# Out:
# ...
# 100%|██████████| 170/170 [01:02<00:00,  2.72it/s]

# %% [markdown]
# # Tweet Sentiment

# %%
nums = [1,2,3,4,5]
for i in nums:
  arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/base_tweet_sentiment_'+str(perc)+'_original'+str(i)+'.csv'
  base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')
  base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
  export = base_cru_1p.copy()
  export = export.explode('generated').reset_index(drop=True)
  arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/checklist/base_tweet_sentiment_'+str(perc)+'_checklist'+str(i)+'.csv'
  export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
# Out:
# ...
# 100%|██████████| 210/210 [00:43<00:00,  4.80it/s]

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/432M [00:00<?, ?B/s]
# 2022-07-01 20:50:54,689 loading file /root/.flair/models/ner-english/4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4
# 2022-07-01 20:50:57,062 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 100%|██████████| 4000/4000 [05:01<00:00, 13.28it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0  i also feel a little selfish when i get excite...      3
# 1  i feel it is equally important that you know i...      1
# 2  i feel it is equally important that you know i...      1
# 3  i feel it is equally important that you know i...      1
# 4  i feel it is equally important that you know i...      1
#
#                                            generated
# 0  i also feel a little selfish when i get excite...
# 1  i feel it is equally important that you know i...
# 2  i feel it is equally important that you know i...
# 3  i feel it's equally important that you know i ...
# 4  i feel it's equally important that you know i ...

# %%
export.shape
# Out:
# (5887, 3)

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_emotions_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # TREC

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_trec_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
# Out:
# 100%|██████████| 1363/1363 [00:36<00:00, 37.45it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0  What 's the American dollar equivalent for 8 p...      4
# 1  What 's the American dollar equivalent for 8 p...      4
# 2  What 's the American dollar equivalent for 8 p...      4
# 3  What 's the American dollar equivalent for 8 p...      4
# 4      What country does Ileana Cotrubas come from ?      5
#
#                                            generated
# 0  What 's the American dollar equivalent for 12 ...
# 1  What 's the American dollar equivalent for 13 ...
# 2  What 's the American dollar equivalent for 4 p...
# 3  What 's the American dollar equivalent for 8 p...
# 4        What country does Ileana Bowker come from ?

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_trec_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # Offensive

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_offensive_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
def aplica_aug(x):
  try:
    res = augmenter.augment(x)
  except:
    res = x
  return res

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].astype('str').progress_apply(lambda x : aplica_aug(x))
# Out:
#   0%|          | 0/2979 [00:00<?, ?it/s]
# 2022-07-01 21:15:51,258 loading file /root/.flair/models/ner-english/4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4
# 2022-07-01 21:15:53,265 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 100%|██████████| 2979/2979 [09:05<00:00,  5.46it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0                                     @user Childess      0
# 1  Confirm the MAN! THE LEFT WING ACTIVIST IS A L...      1
# 2  President Trump's economy is the rising tide t...      0
# 3  President Trump's economy is the rising tide t...      0
# 4  @user @user Businessmen need to stay in busine...      0
#
#                                            generated
# 0                                     @user Childess
# 1  Confirm the MAN! THE LEFT WING ACTIVIST IS A L...
# 2  President Trump's economy is the rising tide t...
# 3  President Trump's economy is the rising tide t...
# 4  @user @user Businessmen need to stay in busine...

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_offensive_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # Ironic

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_ironic_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
# Out:
# 100%|██████████| 716/716 [01:35<00:00,  7.49it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0  @user @user but $7 at a big guy like sephora o...      0
# 1  @user @user but $7 at a big guy like sephora o...      0
# 2  @user @user but $7 at a big guy like sephora o...      0
# 3  @user @user but $7 at a big guy like sephora o...      0
# 4  Enroll 2 Members 1 on each leg (L/R). THEN, he...      0
#
#                                            generated
# 0  @user @user but $10 at a big guy like sephora ...
# 1  @user @user but $12 at a big guy like sephora ...
# 2  @user @user but $14 at a big guy like sephora ...
# 3  @user @user but $6 at a big guy like sephora o...
# 4  Enroll 2 Members 1 on each leg (L/R). THEN, he...

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_ironic_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # Emoint

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_emoint_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
# Out:
# 100%|██████████| 815/815 [00:51<00:00, 15.96it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0  Sounds like Donald Trump has spent today just ...      0
# 1  Sounds like Donald Trump has spent today just ...      0
# 2  Sounds like Donald Trump has spent today just ...      0
# 3  Sounds like Donald Trump has spent today just ...      0
# 4  also i had an awful nightmare involving being ...      3
#
#                                            generated
# 0  Sounds like Abria Leake has spent today just m...
# 1  Sounds like Donald Trump has spent today just ...
# 2  Sounds like Shailyn Dell has spent today just ...
# 3  Sounds like Tarik Wen has spent today just mak...
# 4  also i had an awful nightmare involving being ...

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_emoint_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # Emoji

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_emoji_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : aplica_aug(x))
# Out:
# 100%|██████████| 11250/11250 [05:45<00:00, 32.53it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0  Late meet up.... Fresh from Sweden #friendship...      9
# 1  Late meet up.... Fresh from Sweden #friendship...      9
# 2  Late meet up.... Fresh from Sweden #friendship...      9
# 3  Late meet up.... Fresh from Sweden #friendship...      9
# 4  A big thank you to all the @user sponsors! Tha...      0
#
#                                            generated
# 0  Late meet up.... Fresh from Fiji #friendshipfo...
# 1  Late meet up.... Fresh from Greenland #friends...
# 2  Late meet up.... Fresh from Italy #friendshipf...
# 3  Late meet up.... Fresh from Kenya #friendshipf...
# 4  A big thank you to all the @user sponsors! Tha...

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_emoji_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # Rotten

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_rotten_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
# Out:
# 100%|██████████| 2133/2133 [03:02<00:00, 11.71it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0  the spark of special anime magic here is unmis...      1
# 1  it's as if you're watching a movie that was ma...      0
# 2  it's as if you're watching a movie that was ma...      0
# 3  it's as if you're watching a movie that was ma...      0
# 4  it's as if you're watching a movie that was ma...      0
#
#                                            generated
# 0  the spark of special anime magic here is unmis...
# 1  it is as if you are watching a movie that was ...
# 2  it is as if you're watching a movie that was m...
# 3  it's as if you are watching a movie that was m...
# 4  it's as if you are watching a movie that was m...

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_rotten_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # IMDB

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_imdb_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_imdb_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # AGNEWS

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_agnews_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#                                            generated  \
# 0  and this a given new standard trade in great b...
# 1  great white sharks given new protection trade ...
# 2  great white sharks given new protection result...
# 3  even white sharks given new protection trade f...
# 4  great white sharks said new protection trade i...
#
#                                                texto  label
# 0  Great White Sharks Given New Protection Trade ...      0
# 1  Great White Sharks Given New Protection Trade ...      0
# 2  Great White Sharks Given New Protection Trade ...      0
# 3  Great White Sharks Given New Protection Trade ...      0
# ...

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_agnews_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')

# %% [markdown]
# # SST

# %%
arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_sst_'+str(perc)+'_original1.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p['generated'] = base_cru_1p['texto'].progress_apply(lambda x : augmenter.augment(x))
# Out:
# 100%|██████████| 2136/2136 [03:30<00:00, 10.16it/s]

# %%
export = base_cru_1p.copy()
export = export.explode('generated').reset_index(drop=True)
export.head()
# Out:
#                                                texto  label  \
# 0  Perry 's good and his is an interesting charac...      0
# 1  Perry 's good and his is an interesting charac...      0
# 2  Perry 's good and his is an interesting charac...      0
# 3  Perry 's good and his is an interesting charac...      0
# 4                     ( A ) poorly executed comedy .      0
#
#                                            generated
# 0  Candelario 's good and his is an interesting c...
# 1  Jewell 's good and his is an interesting chara...
# 2  Joesph 's good and his is an interesting chara...
# 3  Savana 's good and his is an interesting chara...
# 4                     ( A ) poorly executed comedy .

# %%
i = 0
arquivo = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/base_sst_'+str(perc)+'_checklist'+str(i+1)+'.csv'
export.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
