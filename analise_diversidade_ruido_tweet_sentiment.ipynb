# %% [markdown]
# Instalando Pacote

# %%
# !pip install textstat
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
perc= 5

# %%
import pandas as pd

i=0


arq =  '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/eda/base_tweet_sentiment_'+str(perc)+'_eda'+str(i+1)+'.csv'
eda = pd.read_csv(arq, sep = ';', decimal = ',')


arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/back_translation/base_tweet_sentiment_'+str(perc)+'_back_translation'+str(i+1)+'.csv'
back_trans = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/base_tweet_sentiment_'+str(perc)+'_original'+str(i+1)+'.csv'
ori = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/teste_algo/base_tweet_sentiment_'+str(perc)+'_gptneokey'+str(i+1)+'.csv'
gptneo = pd.read_csv(arq, sep = ';', decimal = ',')


arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/gptparaphrase/base_tweet_sentiment_'+str(perc)+'_gptparaphrase'+str(i+1)+'.pkl'
llama = pd.read_pickle(arq)


arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/protaugment/base_tweet_sentiment_'+str(perc)+'_protaugment'+str(i+1)+'.csv'
protaug = pd.read_csv(arq, sep = ';', decimal = ',')


arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/lambada/base_tweet_sentiment_'+str(perc)+'_lambada'+str(i+1)+'.csv'
lambada = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/lambada/base_tweet_sentiment_'+str(perc)+'_lambada_contrastive'+str(i+1)+'.csv'
c_lambada = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/checklist/base_tweet_sentiment_'+str(perc)+'_checklist'+str(i+1)+'.csv'
check = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/t5_key_text/perc_' +str(perc) + '/tweet_sentiment/ssmba/base_tweet_sentiment_'+str(perc)+'_ssmba'+str(i+1)+'.csv'
ssmba = pd.read_csv(arq, sep = ';', decimal = ',')

# %%
lambada.head()
# Out:
#                                                texto  \
# 0  "For anyone who likes both Scott Walker and Ba...
# 1  "For anyone who likes both Scott Walker and Ba...
# 2  "For anyone who likes both Scott Walker and Ba...
# 3  "For anyone who likes both Scott Walker and Ba...
# 4  "For anyone who likes both Scott Walker and Ba...
#
#                                            generated  new_label
# 0  "For anyone who likes my movies and may buy a ...          1
# 1  "For anyone who likes comedy, we owe it to you...          1
# 2  "For anyone who likes politics, I want to see ...          1
# 3  "For anyone who likes the Blues, this match wa...          1
# 4  "For anyone who likes the Apple Music app, the...          1

# %%
ori.head()
# Out:
#                                                texto  label
# 0  "For anyone who likes both Scott Walker and Ba...      1
# 1  Netanyahu\u2019s new alliance with Lieberman m...      0
# 2  I did Christians laundry &amp; made him lunch ...      1
# 3  @user @user @user love that camera close up of...      2
# 4  @user @user And David Cameron is 5th cousin of...      1

# %%
import textstat

text = "Your example text goes here. It can be a sentence or a paragraph."

flesch_reading_ease = textstat.flesch_reading_ease(text)
flesch_kincaid_grade = textstat.flesch_kincaid_grade(text)
smog_index = textstat.smog_index(text)
coleman_liau_index = textstat.coleman_liau_index(text)

print(f"Flesch Reading Ease: {flesch_reading_ease}")
print(f"Flesch-Kincaid Grade Level: {flesch_kincaid_grade}")
print(f"SMOG Index: {smog_index}")
print(f"Coleman-Liau Index: {coleman_liau_index}")
# Out:
# Flesch Reading Ease: 90.26
# Flesch-Kincaid Grade Level: 2.3
# SMOG Index: 0.0
# Coleman-Liau Index: 2.5

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
eda['flesch_reading_ease'] = eda['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
ssmba['flesch_reading_ease'] = ssmba['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
check['flesch_reading_ease'] = check['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
back_trans['flesch_reading_ease'] = back_trans['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
lambada['flesch_reading_ease'] = lambada['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
c_lambada['flesch_reading_ease'] = c_lambada['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
protaug['flesch_reading_ease'] = protaug['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
llama['flesch_reading_ease'] = llama['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(str(x)))
gptneo['flesch_reading_ease'] = gptneo['generated'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
ori['flesch_reading_ease'] = ori['texto'].progress_apply(lambda x: textstat.flesch_reading_ease(x))
# Out:
# ...
# 100%|██████████| 210/210 [00:00<00:00, 8414.81it/s]

# %%
eda['flesch_kincaid_grade'] = eda['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
ssmba['flesch_kincaid_grade'] = ssmba['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
check['flesch_kincaid_grade'] = check['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
back_trans['flesch_kincaid_grade'] = back_trans['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
lambada['flesch_kincaid_grade'] = lambada['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
c_lambada['flesch_kincaid_grade'] = c_lambada['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
protaug['flesch_kincaid_grade'] = protaug['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
llama['flesch_kincaid_grade'] = llama['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(str(x)))
gptneo['flesch_kincaid_grade'] = gptneo['generated'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
ori['flesch_kincaid_grade'] = ori['texto'].progress_apply(lambda x: textstat.flesch_kincaid_grade(x))
# Out:
# ...
# 100%|██████████| 210/210 [00:00<00:00, 7365.94it/s]

# %%
eda['smog_index'] = eda['generated'].progress_apply(lambda x: textstat.smog_index(x))
ssmba['smog_index'] = ssmba['generated'].progress_apply(lambda x: textstat.smog_index(x))
check['flesch_kincaid_grade'] = check['generated'].progress_apply(lambda x: textstat.smog_index(x))
back_trans['smog_index'] = back_trans['generated'].progress_apply(lambda x: textstat.smog_index(x))
lambada['smog_index'] = lambada['generated'].progress_apply(lambda x: textstat.smog_index(x))
c_lambada['smog_index'] = c_lambada['generated'].progress_apply(lambda x: textstat.smog_index(x))
protaug['smog_index'] = protaug['generated'].progress_apply(lambda x: textstat.smog_index(x))
llama['smog_index'] = llama['generated'].progress_apply(lambda x: textstat.smog_index(str(x)))
gptneo['smog_index'] = gptneo['generated'].progress_apply(lambda x: textstat.smog_index(x))
ori['smog_index'] = ori['texto'].progress_apply(lambda x: textstat.smog_index(x))
# Out:
# ...
# 100%|██████████| 210/210 [00:00<00:00, 23485.60it/s]

# %%
eda['coleman_liau_index'] = eda['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
ssmba['coleman_liau_index'] = ssmba['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
check['coleman_liau_index'] = check['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
back_trans['coleman_liau_index'] = back_trans['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
lambada['coleman_liau_index'] = lambada['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
c_lambada['coleman_liau_index'] = c_lambada['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
protaug['coleman_liau_index'] = protaug['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
llama['coleman_liau_index'] = llama['generated'].progress_apply(lambda x: textstat.coleman_liau_index(str(x)))
gptneo['coleman_liau_index'] = gptneo['generated'].progress_apply(lambda x: textstat.coleman_liau_index(x))
ori['coleman_liau_index'] = ori['texto'].progress_apply(lambda x: textstat.coleman_liau_index(x))
# Out:
# ...
# 100%|██████████| 210/210 [00:00<00:00, 11135.18it/s]

# %%
ori.describe()
# Out:
#             label  flesch_reading_ease  flesch_kincaid_grade  smog_index  \
# count  210.000000           210.000000            210.000000  210.000000
# mean     1.233333            75.540429              6.288095    0.568095
# std      0.703942            17.493753              3.302805    1.749554
# min      0.000000            28.840000              0.100000    0.000000
# 25%      1.000000            64.922500              3.500000    0.000000
# 50%      1.000000            77.065000              5.900000    0.000000
# 75%      2.000000            88.612500              9.025000    0.000000
# max      2.000000           106.670000             13.800000    7.800000
#
#        coleman_liau_index
# count          210.000000
# mean             7.427238
# std              4.074735
# min             -3.460000
# 25%              4.600000
# 50%              6.815000
# 75%              9.500000
# max             20.910000

# %%
eda.describe()
# Out:
#              label  flesch_reading_ease  flesch_kincaid_grade   smog_index  \
# count  1680.000000          1680.000000           1680.000000  1680.000000
# mean      1.233333            73.452298              6.507679     0.593988
# std       0.702473            18.289466              3.421072     1.854324
# min       0.000000            -3.990000             -0.900000     0.000000
# 25%       1.000000            62.680000              3.800000     0.000000
# 50%       1.000000            75.540000              6.000000     0.000000
# 75%       2.000000            87.050000              9.200000     0.000000
# max       2.000000           114.420000             18.200000     8.800000
#
#        coleman_liau_index
# count         1680.000000
# mean             7.945512
# std              4.189031
# min             -4.710000
# 25%              5.030000
# 50%              7.430000
# 75%             10.290000
# max             24.740000

# %%
ssmba.describe()
# Out:
#              label  flesch_reading_ease  flesch_kincaid_grade   smog_index  \
# count  1050.000000          1050.000000           1050.000000  1050.000000
# mean      1.233333            78.622619              5.730095     0.830190
# std       0.702599            17.050140              3.332512     2.110637
# min       0.000000            12.940000             -1.700000     0.000000
# 25%       1.000000            68.100000              3.100000     0.000000
# 50%       1.000000            80.700000              5.200000     0.000000
# 75%       2.000000            90.727500              8.400000     0.000000
# max       2.000000           116.450000             15.400000     9.700000
#
#        coleman_liau_index
# count         1050.000000
# mean             6.484819
# std              3.777628
# min             -4.570000
# 25%              3.965000
# 50%              6.120000
# 75%              8.630000
# max             23.020000

# %%
check.describe()
# Out:
#             label  flesch_reading_ease  flesch_kincaid_grade  \
# count  771.000000           771.000000             771.00000
# mean     1.198444            74.225811               0.45201
# std      0.706774            17.177788               1.57529
# min      0.000000            21.400000               0.00000
# 25%      1.000000            64.040000               0.00000
# 50%      1.000000            75.540000               0.00000
# 75%      2.000000            86.625000               0.00000
# max      2.000000           107.180000               8.80000
#
#        coleman_liau_index
# count          771.000000
# mean             7.809857
# std              3.941001
# min             -4.040000
# 25%              5.030000
# 50%              7.370000
# 75%              9.915000
# max             20.910000

# %%
back_trans.describe()
# Out:
#             label  flesch_reading_ease  flesch_kincaid_grade  smog_index  \
# count  210.000000           210.000000            210.000000  210.000000
# mean     1.233333            62.227905             11.676667    6.442381
# std      0.703942            34.368511             12.154271    4.246796
# min      0.000000           -50.670000              0.200000    0.000000
# 25%      1.000000            52.900000              4.400000    3.100000
# 50%      1.000000            73.150000              7.250000    7.300000
# 75%      2.000000            84.065000             10.875000    9.200000
# max      2.000000           106.570000             57.100000   15.900000
#
#        coleman_liau_index
# count          210.000000
# mean             7.602952
# std              4.044236
# min             -1.720000
# 25%              4.795000
# 50%              7.055000
# 75%              9.687500
# max             22.710000

# %%
lambada.describe()
# Out:
#          new_label  flesch_reading_ease  flesch_kincaid_grade   smog_index  \
# count  1050.000000          1050.000000            1050.00000  1050.000000
# mean      1.010476            78.689295               5.04181     0.036667
# std       0.101864            22.887648               3.27225     0.464034
# min       1.000000          -132.590000              -3.50000     0.000000
# 25%       1.000000            70.130000               2.90000     0.000000
# 50%       1.000000            81.630000               4.80000     0.000000
# 75%       1.000000            92.800000               6.80000     0.000000
# max       2.000000           121.220000              32.00000     8.800000
#
#        coleman_liau_index
# count         1050.000000
# mean             6.107933
# std              6.006233
# min            -22.210000
# 25%              2.860000
# 50%              5.515000
# 75%              8.230000
# max             88.000000

# %%
c_lambada.describe()
# Out:
#          new_label  flesch_reading_ease  flesch_kincaid_grade   smog_index  \
# count  1050.000000          1050.000000           1050.000000  1050.000000
# mean      1.085714            76.692229              4.717714     0.002952
# std       0.773911            58.172663              7.933701     0.095668
# min       0.000000          -809.390000            -15.700000     0.000000
# 25%       0.000000            68.770000              2.100000     0.000000
# 50%       1.000000            84.680000              3.700000     0.000000
# 75%       2.000000            98.550000              6.000000     0.000000
# max       2.000000           206.840000            126.400000     3.100000
#
#        coleman_liau_index
# count         1050.000000
# mean             5.212438
# std             14.316228
# min            -28.010000
# 25%              1.380000
# 50%              4.180000
# 75%              7.687500
# max            198.200000

# %%
protaug.describe()
# Out:
#              label  flesch_reading_ease  flesch_kincaid_grade   smog_index  \
# count  1680.000000          1680.000000           1680.000000  1680.000000
# mean      1.233333            76.111982              6.350000     0.319286
# std       0.702473            17.018104              3.180519     1.321670
# min       0.000000             7.520000              0.100000     0.000000
# 25%       1.000000            66.070000              3.700000     0.000000
# 50%       1.000000            77.740000              6.000000     0.000000
# 75%       2.000000            88.060000              9.100000     0.000000
# max       2.000000           112.090000             15.400000     7.800000
#
#        coleman_liau_index
# count         1680.000000
# mean             7.276732
# std              3.874088
# min             -3.750000
# 25%              4.570000
# 50%              6.620000
# 75%              9.550000
# max             23.420000

# %%
llama.describe()
# Out:
#              label  flesch_reading_ease  flesch_kincaid_grade   smog_index  \
# count  1022.000000          1022.000000           1022.000000  1022.000000
# mean      1.220157            75.011585              5.753229     0.385421
# std       0.703611            19.098814              3.148848     1.546179
# min       0.000000           -20.240000             -3.500000     0.000000
# 25%       1.000000            62.340000              3.500000     0.000000
# 50%       1.000000            77.230000              5.600000     0.000000
# 75%       2.000000            88.205000              8.000000     0.000000
# max       2.000000           121.220000             17.800000    11.400000
#
#        coleman_liau_index
# count         1022.000000
# mean             7.938845
# std              4.224453
# min            -28.010000
# 25%              5.260000
# 50%              7.430000
# 75%             10.610000
# max             24.580000

# %%
gptneo.describe()
# Out:
#          new_label    prob_text  flesch_reading_ease  flesch_kincaid_grade  \
# count  1050.000000  1050.000000          1050.000000           1050.000000
# mean      1.233333     0.912557            73.446657              5.582095
# std       0.702599     0.091885            80.136790             11.201304
# min       0.000000     0.575562         -1232.390000            -15.700000
# 25%       1.000000     0.889513            65.220000              2.425000
# 50%       1.000000     0.953224            81.630000              4.800000
# 75%       2.000000     0.974675            95.170000              7.600000
# max       2.000000     0.987359           206.840000            185.400000
#
#         smog_index  coleman_liau_index
# count  1050.000000         1050.000000
# mean      0.411048            9.633105
# std       1.581739           26.819959
# min       0.000000          -28.010000
# 25%       0.000000            2.857500
# 50%       0.000000            5.610000
# ...
