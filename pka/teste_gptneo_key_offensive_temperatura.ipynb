# %% [markdown]
# # Imports and Setups

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 11.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 66.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.6 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 3.7 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for accelerate (pyproject.toml) ... done

# %%
! pip install setfit
# Out:
# Collecting setfit
#   Downloading setfit-0.7.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.6 MB/s eta 0:00:00
# Collecting datasets>=2.3.0 (from setfit)
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 11.6 MB/s eta 0:00:00
# Collecting sentence-transformers>=2.2.1 (from setfit)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting evaluate>=0.3.0 (from setfit)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=2.3.0->setfit)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.4.1)
# Collecting multiprocess (from datasets>=2.3.0->setfit)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.8.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.17.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (6.0.1)
# Collecting responses<0.19 (from evaluate>=0.3.0->setfit)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (4.35.0.dev0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.16.0+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=2.2.1->setfit)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.3.0->setfit) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.3.0->setfit) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2023.7.22)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.1->setfit) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=2.2.1->setfit) (9.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=2.3.0->setfit) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=9300a5dbe08709e9239b75ff1eff35124ecd94b2487efba24dae2e3b79565f2f
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, dill, responses, multiprocess, datasets, sentence-transformers, evaluate, setfit
# Successfully installed datasets-2.14.6 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 responses-0.18.0 sentence-transformers-2.2.2 sentencepiece-0.1.99 setfit-0.7.0

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.8.3.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.10/dist-packages (from keybert) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.23.5)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.35.0.dev0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Building wheels for collected packages: keybert
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.3-py3-none-any.whl size=39124 sha256=d9739ab03678ab597bf128c4028c43277a020c0da399aeb71d18fac2b1fe6c6d
#   Stored in directory: /root/.cache/pip/wheels/70/88/07/1a3bc11fd1dd5f89924a02dcbca89a3015e25e8faa31f904dc
# Successfully built keybert
# Installing collected packages: keybert
# Successfully installed keybert-0.8.3

# %% [markdown]
# Lendo o Arquivo

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# %%
num_gen = 5
perc = 5
temperatura = 0.99
i=1

# %%
arq = '/content/drive/My Drive/Colab Notebooks/teste_parametros_pka/perc_' +str(perc) + '/offensive/base_offensive_'+str(perc)+'_original'+str(i)+'.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p.head()
# Out:
#                                                texto  label
# 0  @user @user @user I’m really not on any side o...      1
# 1  @user @user Not all of us Conservatives are th...      0
# 2  Here is an Awesome Video of Alex Jones invadin...      0
# 3  @user Bs. He is looking for retirement money a...      0
# 4  @user @user @user Oh boy just wait! YOU ARE IN...      1

# %%
n_labels = base_cru_1p.label.nunique()
n_labels
# Out:
# 2

# %%
from datasets import Dataset, DatasetDict

train = Dataset.from_pandas(base_cru_1p)

# %%
from sentence_transformers.losses import CosineSimilarityLoss

from setfit import SetFitModel, SetFitTrainer, sample_dataset

# %%
train_dataset = sample_dataset(train, label_column="label", num_samples=16)

# %%
train_dataset
# Out:
# Dataset({
#     features: ['texto', 'label'],
#     num_rows: 32
# })

# %%
from sklearn.metrics import f1_score, accuracy_score
import numpy as np

def f1_multiclass(labels, preds):
      return f1_score(labels, preds, average='macro')

# %%
classifica = SetFitModel.from_pretrained(
    "sentence-transformers/paraphrase-mpnet-base-v2",
    # use_differentiable_head=True,
    # head_params={"out_features": 6},
)
# Out:
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
trainer = SetFitTrainer(
    model=classifica,
    train_dataset=train_dataset,
    # eval_dataset=eval,
    loss_class=CosineSimilarityLoss,
    # metric=f1_multiclass,
    batch_size=16,
    num_iterations=20, # The number of text pairs to generate for contrastive learning 40
    num_epochs=1, # The number of epochs to use for contrastive learning
    column_mapping={"texto": "text", "label": "label"} # Map dataset columns to text/label expected by trainer
)

# %%
trainer.train()
# Out:
# Applying column mapping to training dataset
# Generating Training Pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# ***** Running training *****
#   Num examples = 1280
#   Num epochs = 1
#   Total optimization steps = 80
#   Total train batch size = 16
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/80 [00:00<?, ?it/s]

# %%
pred = classifica(base_cru_1p.texto.values)

# %%
f1_multiclass(base_cru_1p.label.values, pred.tolist())
# Out:
# 0.6898245614035088

# %%
trainer.model._save_pretrained(save_directory="./setfit_output/")

# %%
def retorna_word(lista_palavras):
  res = []
  for a in lista_palavras:
    res.append(a[0])
  return res

# %%
from keybert import KeyBERT
kw_model = KeyBERT(model = "./setfit_output/")

# %%
base_cru_1p['keys'] = base_cru_1p['texto'].progress_apply(lambda x:retorna_word(kw_model.extract_keywords(x, keyphrase_ngram_range=(1, 3), top_n=3, use_mmr=True, stop_words = None)))
# Out:
# 100%|██████████| 170/170 [00:13<00:00, 12.62it/s]

# %%
base_cru_1p.head()
# Out:
#                                                texto  label  \
# 0  @user @user @user I’m really not on any side o...      1
# 1  @user @user Not all of us Conservatives are th...      0
# 2  Here is an Awesome Video of Alex Jones invadin...      0
# 3  @user Bs. He is looking for retirement money a...      0
# 4  @user @user @user Oh boy just wait! YOU ARE IN...      1
#
#                                                 keys
# 0  [shit jsjdhkdfhjfkfkhsjdhd messsssss, really n...
# 1  [gullible manny has, us conservatives are, use...
# 2  [user user, vaxxed readthebook cdcwhistleblowe...
# 3            [bs he is, looking for retirement, job]
# 4   [be that ignorant, user oh boy, in for surprise]

# %%
base_cru_1p['keys_text'] = base_cru_1p['keys'].progress_apply(lambda x: " - ".join(x))
base_cru_1p.head()
# Out:
# 100%|██████████| 170/170 [00:00<00:00, 135300.13it/s]
#                                                texto  label  \
# 0  @user @user @user I’m really not on any side o...      1
# 1  @user @user Not all of us Conservatives are th...      0
# 2  Here is an Awesome Video of Alex Jones invadin...      0
# 3  @user Bs. He is looking for retirement money a...      0
# 4  @user @user @user Oh boy just wait! YOU ARE IN...      1
#
#                                                 keys  \
# 0  [shit jsjdhkdfhjfkfkhsjdhd messsssss, really n...
# 1  [gullible manny has, us conservatives are, use...
# 2  [user user, vaxxed readthebook cdcwhistleblowe...
# 3            [bs he is, looking for retirement, job]
# 4   [be that ignorant, user oh boy, in for surprise]
#
#                                            keys_text
# 0  shit jsjdhkdfhjfkfkhsjdhd messsssss - really n...
# 1  gullible manny has - us conservatives are - us...
# 2  user user - vaxxed readthebook cdcwhistleblowe...
# 3            bs he is - looking for retirement - job
# 4   be that ignorant - user oh boy - in for surprise

# %%
pos_key = {}
for c in base_cru_1p['label'].unique():
  data = base_cru_1p[base_cru_1p['label']==c].copy()
  original = data[['keys_text', 'texto', 'label']].values.tolist()

  pos_key[c] = original

  print(len(pos_key[c]))
# Out:
# 56
# 114

# %%
from random import sample

examples = []
generate = []
original = []
labels = []

for c in base_cru_1p['label'].unique():
  for n in range(int(2*num_gen*len(pos_key[c]))):
    if len(pos_key[c]) > 11:
      amostra = sample(pos_key[c],11)
    else:
      amostra = sample(pos_key[c],len(pos_key[c]))

    gen = amostra.pop()

    examples.append(amostra)
    generate.append(gen[0])
    original.append(gen[1])
    labels.append(gen[2])


data_fim = {'examples':examples, 'generate':generate, 'original':original, 'labels':labels}

base_gen = pd.DataFrame.from_dict(data_fim)
base_gen.head()
# Out:
#                                             examples  \
# 0  [[good he mess - mess - user good, @user Good....
# 1  [[slamming chris hayes - love rapist - putin p...
# 2  [[big dick wrong - spelled big dick - user he ...
# 3  [[drunk as shit - was definitely drunk - user ...
# 4  [[an evil hateful - real racist he - he amp ob...
#
#                                             generate  \
# 0  is disgusting statement - with unhinged libera...
# 1  that stopkavanagh repeatedly - is unfit to - u...
# 2     hit on me - boys who hang - avoid the freshman
# 3               bad bitch now - user bad bitch - lol
# 4  shitty ghetto overrun - user dishonored - with...
#
#                                             original  labels
# 0  .@USER is staffed with unhinged Liberals &amp;...       1
# 1  @user Just the fact that #StopKavanagh REPEATE...       1
# 2  @user me trying to avoid the freshman boys who...       1
# 3                        @user U a bad bitch now lol       1
# 4  @user Dishonored zone where you have to balanc...       1

# %%
base_gen.shape
# Out:
# (1700, 4)

# %%
def cria_prompt(classe, ex, synt):
  prompt = "Generate a tweet with this few keywords:"
  for el in ex:
    soma = '\nkeys: '+ el[0]+'\ntweet: '+el[1]+'\n###'
    prompt+= soma

  prompt += '\nkeys: '+ synt+'\ntweet: '
  return prompt

# %%
dict_label ={0:'non-offensive', 1:'offensive'}
base_gen['class_name']= base_gen['labels'].map(dict_label)
base_gen.head()
# Out:
#                                             examples  \
# 0  [[good he mess - mess - user good, @user Good....
# 1  [[slamming chris hayes - love rapist - putin p...
# 2  [[big dick wrong - spelled big dick - user he ...
# 3  [[drunk as shit - was definitely drunk - user ...
# 4  [[an evil hateful - real racist he - he amp ob...
#
#                                             generate  \
# 0  is disgusting statement - with unhinged libera...
# 1  that stopkavanagh repeatedly - is unfit to - u...
# 2     hit on me - boys who hang - avoid the freshman
# 3               bad bitch now - user bad bitch - lol
# 4  shitty ghetto overrun - user dishonored - with...
#
#                                             original  labels class_name
# 0  .@USER is staffed with unhinged Liberals &amp;...       1  offensive
# 1  @user Just the fact that #StopKavanagh REPEATE...       1  offensive
# 2  @user me trying to avoid the freshman boys who...       1  offensive
# 3                        @user U a bad bitch now lol       1  offensive
# 4  @user Dishonored zone where you have to balanc...       1  offensive

# %%
base_gen['prompt'] = base_gen.progress_apply(lambda x: cria_prompt(x.class_name, x.examples, x.generate), axis=1)
base_gen.head()
# Out:
# 100%|██████████| 1700/1700 [00:00<00:00, 30650.89it/s]
#                                             examples  \
# 0  [[good he mess - mess - user good, @user Good....
# 1  [[slamming chris hayes - love rapist - putin p...
# 2  [[big dick wrong - spelled big dick - user he ...
# 3  [[drunk as shit - was definitely drunk - user ...
# 4  [[an evil hateful - real racist he - he amp ob...
#
#                                             generate  \
# 0  is disgusting statement - with unhinged libera...
# 1  that stopkavanagh repeatedly - is unfit to - u...
# 2     hit on me - boys who hang - avoid the freshman
# 3               bad bitch now - user bad bitch - lol
# 4  shitty ghetto overrun - user dishonored - with...
#
#                                             original  labels class_name  \
# 0  .@USER is staffed with unhinged Liberals &amp;...       1  offensive
# 1  @user Just the fact that #StopKavanagh REPEATE...       1  offensive
# 2  @user me trying to avoid the freshman boys who...       1  offensive
# 3                        @user U a bad bitch now lol       1  offensive
# 4  @user Dishonored zone where you have to balanc...       1  offensive
#
#                                               prompt
# 0  Generate a tweet with this few keywords:\nkeys...
# 1  Generate a tweet with this few keywords:\nkeys...
# 2  Generate a tweet with this few keywords:\nkeys...
# 3  Generate a tweet with this few keywords:\nkeys...
# 4  Generate a tweet with this few keywords:\nkeys...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

device = "cuda:0"

model_id = "EleutherAI/gpt-neo-2.7B"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model_4bit = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map="auto")
# model_4bit = model_4bit.to(device)
# Out:
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the .
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu/disk.

# %%
def gera_text(modelo, tokens, dev, ppt, temperatura, max_tokens):
  inputs = tokens(ppt, return_tensors="pt").to(dev)
  outputs = modelo.generate(**inputs, max_new_tokens=max_tokens, temperature=temperatura, do_sample =True)
  result = tokenizer.decode(outputs[0], skip_special_tokens=True)
  return result

# %%
print(gera_text(model_4bit, tokenizer, device,base_gen['prompt'].iloc[4], temperatura, 30))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generate a tweet with this few keywords:
# keys: an evil hateful - real racist he - he amp obama
# tweet: @user Holder is an evil, hateful, dangerous man.  He's a real"" racist.  He absolutely hates White People.  He &amp; Obama contributed to the race riots during O's Admin.""
# ###
# keys: really sexually harassed - it shows liberals - to block nomination
# tweet: @user @user This is purely a move to block a nomination. Liberals said early on they would not vote for him. This made up story is a slap in the face to all who were really sexually harassed. It shows liberals really don’t care about any true victims. Power first.
# ###
# keys: corruption and they - don want american - maga
# tweet: WHY... it's their trail of corruption... and they have so much of it going on, and at all times, they don't want any slips""... don't want American people to know who they really are AND WHAT THEY'VE BEEN UP TO... #MAGA
# ###
# keys: so fucking - spanish it so - user still better
# tweet: @user Still better than Spanish it's so fucking boring and the teacher grades us based on how sexually active we are 😒
# ###
# keys: brutality she should - user who in - died at home
# tweet: @user who in America isn't grateful to our military?!?!? Her husband didn't die on the battle field...he died at home!! She should be fighting for gun control and stronger laws regarding mental illness! @user is about police brutality...she should educate herself on the issues
# ###
# keys: homicides your - user user user - give shit about
# tweet: @user @user @user And your gun control has failed to reduce homicides.  Your homicide rate has not dropped after all of those gun laws.  It has however rose.  Enjoy bending a knee to the people who don't really give a shit about you though.
# ###
# keys: fuck the nfl - user fuck the - the
# tweet: @user Fuck the NFL
# ###
# keys: really that stupid - never see jury - will be settled
# tweet: @user This will be settled and will never see a jury. We will never know the truth. Maybe she grabbed him first while swapping spit or he is really that stupid to just grab her. Either way I doubt we will ever know the complete truth.
# ###
# keys: user hey ladies - right about jon - nights with jesse
# tweet: @user Hey Ladies watch you on Saturday nights with Jesse keep up the good work and your right about Jon Voight he is a Gods man and bless his heart for standing up for the President mean evil people out their who are mad and Dangerous we all want hope and Change for America
# ###
# keys: big dick wrong - spelled big dick - user he spelled
# tweet: @user He spelled Big Dick wrong.
# ###
# keys: shitty ghetto overrun - user dishonored - with rats and
# tweet:  @user @user My parents ghetto run. You will no longer be able to stay with us at night you will be able to sleep at home tonight

# %%
device = "cuda:0"
base_gen['gpt_resp'] = base_gen['prompt'].progress_apply(lambda x: gera_text(model_4bit, tokenizer, device, x, temperatura, 30))
# Out:
#   0%|          | 0/1700 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          |
  3.97s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  99%|█████████▉| 1690/1700 [1:48:47<00:38,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  99%|█████████▉| 1691/1700 [1:48:51<00:34,  3.80s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1692/1700 [1:48:55<00:30,  3.78s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1693/1700 [1:48:59<00:28,  4.05s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1694/1700 [1:49:03<00:23,  3.99s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1695/1700 [1:49:07<00:19,  3.83s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1696/1700 [1:49:10<00:15,  3.78s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1697/1700 [1:49:15<00:12,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1698/1700 [1:49:19<00:07,  3.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|█████████▉| 1699/1700 [1:49:22<00:03,  3.77s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 1700/1700 [1:49:26<00:00,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 1700/1700 [1:49:30<00:00,  3.87s/it]

# %%
base_gen.head()
# Out:
#                                             examples  \
# 0  [[good he mess - mess - user good, @user Good....
# 1  [[slamming chris hayes - love rapist - putin p...
# 2  [[big dick wrong - spelled big dick - user he ...
# 3  [[drunk as shit - was definitely drunk - user ...
# 4  [[an evil hateful - real racist he - he amp ob...
#
#                                             generate  \
# 0  is disgusting statement - with unhinged libera...
# 1  that stopkavanagh repeatedly - is unfit to - u...
# 2     hit on me - boys who hang - avoid the freshman
# 3               bad bitch now - user bad bitch - lol
# 4  shitty ghetto overrun - user dishonored - with...
#
#                                             original  labels class_name  \
# 0  .@USER is staffed with unhinged Liberals &amp;...       1  offensive
# 1  @user Just the fact that #StopKavanagh REPEATE...       1  offensive
# 2  @user me trying to avoid the freshman boys who...       1  offensive
# 3                        @user U a bad bitch now lol       1  offensive
# 4  @user Dishonored zone where you have to balanc...       1  offensive
#
#                                               prompt  \
# 0  Generate a tweet with this few keywords:\nkeys...
# 1  Generate a tweet with this few keywords:\nkeys...
# 2  Generate a tweet with this few keywords:\nkeys...
# 3  Generate a tweet with this few keywords:\nkeys...
# 4  Generate a tweet with this few keywords:\nkeys...
#
#                                             gpt_resp
# 0  Generate a tweet with this few keywords:\nkeys...
# 1  Generate a tweet with this few keywords:\nkeys...
# 2  Generate a tweet with this few keywords:\nkeys...
# 3  Generate a tweet with this few keywords:\nkeys...
# 4  Generate a tweet with this few keywords:\nkeys...

# %%
def separa_resp(gerar, resp):
  fim = resp.split(gerar+'\ntweet:')[1]
  return fim.split('###')[0].replace('\n', '')

# %%
base_gen['gen_fim'] = base_gen.progress_apply(lambda x: separa_resp(x.generate, x.gpt_resp), axis=1)
base_gen.head()
# Out:
# 100%|██████████| 1700/1700 [00:00<00:00, 38866.00it/s]
#                                             examples  \
# 0  [[good he mess - mess - user good, @user Good....
# 1  [[slamming chris hayes - love rapist - putin p...
# 2  [[big dick wrong - spelled big dick - user he ...
# 3  [[drunk as shit - was definitely drunk - user ...
# 4  [[an evil hateful - real racist he - he amp ob...
#
#                                             generate  \
# 0  is disgusting statement - with unhinged libera...
# 1  that stopkavanagh repeatedly - is unfit to - u...
# 2     hit on me - boys who hang - avoid the freshman
# 3               bad bitch now - user bad bitch - lol
# 4  shitty ghetto overrun - user dishonored - with...
#
#                                             original  labels class_name  \
# 0  .@USER is staffed with unhinged Liberals &amp;...       1  offensive
# 1  @user Just the fact that #StopKavanagh REPEATE...       1  offensive
# 2  @user me trying to avoid the freshman boys who...       1  offensive
# 3                        @user U a bad bitch now lol       1  offensive
# 4  @user Dishonored zone where you have to balanc...       1  offensive
#
#                                               prompt  \
# 0  Generate a tweet with this few keywords:\nkeys...
# 1  Generate a tweet with this few keywords:\nkeys...
# 2  Generate a tweet with this few keywords:\nkeys...
# 3  Generate a tweet with this few keywords:\nkeys...
# 4  Generate a tweet with this few keywords:\nkeys...
#
#                                             gpt_resp  \
# 0  Generate a tweet with this few keywords:\nkeys...
# 1  Generate a tweet with this few keywords:\nkeys...
# 2  Generate a tweet with this few keywords:\nkeys...
# 3  Generate a tweet with this few keywords:\nkeys...
# 4  Generate a tweet with this few keywords:\nkeys...
#
#                                              gen_fim
# 0     Is #RapeGate not a disgusting statement fro...
# 1    @user that stopped the vote suppression movi...
# 2    #@_@  How are you all doing today guys? Hope...
# 3                                        @user @user
# 4    @user They took my ghetto home and gave them...

# %%
teste = base_gen[base_gen['gen_fim']!= ' '].copy()
teste.shape
# Out:
# (1652, 8)

# %%
exp_lambada = []

limiar = 1.2/n_labels
base_gen = base_gen[~(base_gen['gen_fim'].isin(["ERRO",'',' ', '\n']))].copy()
preds = classifica.predict_proba(base_gen['gen_fim'].to_list()).tolist()
base_gen['preds'] = [preds[i] for i in range(len(preds))]
base_gen['prob_text'] = base_gen.progress_apply(lambda x:(x.preds[x.labels]), axis=1)
# fim = base_gen[base_gen['prob_text']>= limiar].copy()
fim = base_gen.copy()
fim.rename(columns = {'original':'texto', 'gen_fim':'generated', 'labels':'new_label'}, inplace = True)


exp_lambada.append(fim[['texto','generated', 'new_label', 'prob_text']].copy())
# Out:
# 100%|██████████| 1652/1652 [00:00<00:00, 35471.80it/s]

# %%
exp_lambada[0].shape
# Out:
# (1652, 4)

# %%
base_cru_1p.shape
# Out:
# (170, 4)

# %%
exp_lambada[0].shape[0]/base_cru_1p.shape[0]
# Out:
# 9.717647058823529

# %%
fim = []

for c in base_cru_1p.label.unique():
  limite = base_cru_1p[base_cru_1p.label==c].copy().shape[0]*num_gen
  gerados = exp_lambada[0][exp_lambada[0]['new_label']==c].copy()
  # gerados = gerados.drop_duplicates(subset = ['generated'])

  gerados = gerados.sort_values(by='prob_text', ascending=False)
  gerados = gerados.head(limite)
  fim.append(gerados)

# %%
base_aug_fim = pd.concat(fim)
base_aug_fim.head()
# Out:
#                                                  texto  \
# 339  @user @user Tbere aren't hardly any Conservati...
# 470                           @user He's beyond moron.
# 214                           @user He's beyond moron.
# 392                           @user He's beyond moron.
# 513  Same here but the more he talks the dumber he ...
#
#                                              generated  new_label  prob_text
# 339                                Just unhinged-Robo!          1   0.985314
# 470                  He goes beyond moron into #moron.          1   0.984236
# 214    @user @user @user @user @user @user @user Ba...          1   0.983711
# 392    He is beyond stupid &amp;a very rude man. It...          1   0.983607
# 513                           @user he looks retarded.          1   0.982845

# %%
base_aug_fim.shape[0]/base_cru_1p.shape[0]
# Out:
# 5.0

# %%
arquivo = '/content/drive/My Drive/Colab Notebooks/teste_parametros_pka/perc_' +str(perc) + '/offensive/temperatura/base_offensive_temperatura_'+str(temperatura)+'.csv'
base_aug_fim.to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
